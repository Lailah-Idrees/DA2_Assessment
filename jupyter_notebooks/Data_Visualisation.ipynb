# %% [markdown]
# # **Stroke Predictions - Data Visualisation**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Lailah\\vscode-project\\DA2_Assessment\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Lailah\\vscode-project\\DA2_Assessment'

# %% [markdown]
# # Section 1

# %% [markdown]
# Loading Clean Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("../Data/Cleaned_Data/Cleaned_Data.csv")
df.head(8)
# Out:
#    hypertension  heart_disease   bmi weight_category  avg_glucose_level  \
# 0             0              1  36.6           Obese           169.3575
# 1             0              0  28.1      Overweight           169.3575
# 2             0              1  32.5           Obese           105.9200
# 3             0              0  34.4           Obese           169.3575
# 4             1              0  24.0         Healthy           169.3575
# 5             0              0  29.0      Overweight           169.3575
# 6             1              1  27.4      Overweight            70.0900
# 7             0              0  22.8         Healthy            94.3900
#
#    stroke  gender  gender_Male  gender_Other   age ever_married  \
# 0       1    Male          1.0           0.0  67.0          Yes
# 1       1  Female          0.0           0.0  61.0          Yes
# 2       1    Male          1.0           0.0  80.0          Yes
# ...

# %%
df.tail(8)
# Out:
#       hypertension  heart_disease   bmi weight_category  avg_glucose_level  \
# 5102             0              0  21.7         Healthy              77.93
# 5103             0              0  46.3  severely Obese              82.85
# 5104             0              0  18.6         Healthy             103.08
# 5105             1              0  28.1      Overweight              83.75
# 5106             0              0  40.0  severely Obese             125.20
# 5107             0              0  30.6           Obese              82.99
# 5108             0              0  25.6      Overweight             166.29
# 5109             0              0  26.2      Overweight              85.28
#
#       stroke  gender  gender_Male  gender_Other   age ever_married  \
# 5102       0  Female          0.0           0.0  57.0          Yes
# 5103       0  Female          0.0           0.0  18.0           No
# 5104       0  Female          0.0           0.0  13.0           No
# ...

# %%
types = df.dtypes
print(types)
# Out:
# hypertension              int64
# heart_disease             int64
# bmi                     float64
# weight_category          object
# avg_glucose_level       float64
# stroke                    int64
# gender                   object
# gender_Male             float64
# gender_Other            float64
# age                     float64
# ever_married             object
# ever_married_Yes        float64
# Residence_type           object
# Residence_type_Urban    float64
# work_type                object
# work_type_encoded       float64
# dtype: object

# %%
df.shape
# Out:
# (5110, 16)

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Univariate Analysis

# %%
fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(15,10))
sns.countplot(x=df["gender"], ax=axes[0][0])
#sns.countplot(x=df["weight_category"], ax=axes[0][1])
sns.countplot(x=df["Residence_type"], ax=axes[1][0])
sns.countplot(x=df["work_type"], ax=axes[1][1])

sns.countplot(x=df["ever_married"], ax=axes[0][1])
axes[0][1].set_xticks([0, 1])
axes[0][1].set_xticklabels(["No", "Yes"])
axes[0][1].set_title("Ever Married Count (Yes vs No)")
axes[0][1].set_xlabel("Ever Married")
axes[0][1].set_ylabel("Count")

plt.tight_layout()

plt.show()

# %%
fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(15,10))

sns.countplot(data=df, x="heart_disease", ax=axes[0][0]) 
axes[0][0].set_xticks([0, 1])
axes[0][0].set_xticklabels(["No", "Yes"])
axes[0][0].set_title("Heart Disease Count (Yes vs No)") 
axes[0][0].set_xlabel("Heart Disease") 
axes[0][0].set_ylabel("Count")

sns.countplot(data=df, x="hypertension", ax=axes[0][1]) 
axes[0][1].set_xticks([0, 1])
axes[0][1].set_xticklabels(["No", "Yes"])
axes[0][1].set_title("Hypertension Count (Yes vs No)") 
axes[0][1].set_xlabel("Hypertension") 
axes[0][1].set_ylabel("Count")

sns.countplot(data=df, x="stroke", ax=axes[1][0]) 
axes[1][0].set_xticks([0, 1])
axes[1][0].set_xticklabels(["No", "Yes"])
axes[1][0].set_title("Stroke Count (Yes vs No)") 
axes[1][0].set_xlabel("Stroke") 
axes[1][0].set_ylabel("Count")

order = ["Underweight", "Healthy", "Overweight", "Obese", "severely Obese"]
sns.countplot(x=df["weight_category"], ax=axes[1][1], order=order)


plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %% [markdown]
# Weight Analysis

# %% [markdown]
# To remind us of the dataset

# %%
df.head(8)
# Out:
#    hypertension  heart_disease   bmi weight_category  avg_glucose_level  \
# 0             0              1  36.6           Obese           169.3575
# 1             0              0  28.1      Overweight           169.3575
# 2             0              1  32.5           Obese           105.9200
# 3             0              0  34.4           Obese           169.3575
# 4             1              0  24.0         Healthy           169.3575
# 5             0              0  29.0      Overweight           169.3575
# 6             1              1  27.4      Overweight            70.0900
# 7             0              0  22.8         Healthy            94.3900
#
#    stroke  gender  gender_Male  gender_Other   age ever_married  \
# 0       1    Male          1.0           0.0  67.0          Yes
# 1       1  Female          0.0           0.0  61.0          Yes
# 2       1    Male          1.0           0.0  80.0          Yes
# ...

# %%
plt.figure(figsize=(10,6))
sns.lmplot(data=df, x='age', y='bmi', hue='gender', height=5, aspect=1.5)
sns.lmplot(data=df, x='age', y='bmi', hue='stroke', height=5, aspect=1.5)
sns.lmplot(data=df, x='age', y='bmi', hue='hypertension', height=5, aspect=1.5)
sns.lmplot(data=df, x='age', y='bmi', hue='heart_disease', height=5, aspect=1.5)
plt.show()

# %%
# Fix: handle environments where sns.striplot is not available
fig,axes = plt.subplots(nrows=3, ncols=2, figsize=(15,10))

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='gender', jitter=0.25, alpha=0.6, ax=axes[0][0])
    axes[0][0].legend(
    title="Gender",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["gender"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='weight_category', jitter=0.25, alpha=0.6, ax=axes[0][1])
    axes[0][1].legend(
    title="Weight Category",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["weight_category"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='work_type', jitter=0.25, alpha=0.6, ax=axes[1][0])
    axes[1][0].legend(
    title="Work Type",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["work_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='Residence_type', jitter=0.25, alpha=0.6, ax=axes[1][1])
    axes[1][1].legend(
        title="Residence Type",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["Residence_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='heart_disease', jitter=0.25, alpha=0.6, ax=axes[2][0])
    axes[2][0].legend(
        title="Heart Disease",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["heart_disease"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='age', hue='hypertension', jitter=0.25, alpha=0.6, ax=axes[2][1])
    axes[2][1].legend(
    title="Hypertension",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
    plt.legend(
        title="Hypertension",
        bbox_to_anchor=(1.05, 1),
        loc="upper left",
        borderaxespad=0
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["age"],
        hue=df["hypertension"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])
plt.tight_layout()
plt.show()

# %%
fig,axes = plt.subplots(nrows=3, ncols=2, figsize=(15,10))
sns.boxplot(data=df, x='stroke', y='age',hue='gender', ax=axes[0][0])
axes[0][0].legend(
title="gender",
bbox_to_anchor=(1.05, 1),
loc="upper left"
)

sns.boxplot(data=df, x='stroke', y='age', hue='weight_category', ax=axes[0][1])
axes[0][1].legend(
title="Weight Category",
bbox_to_anchor=(1.05, 1),
loc="upper left"
)

sns.boxplot(data=df, x='stroke', y='age', hue='work_type', ax=axes[1][0])
axes[1][0].legend(
title="Work Type",
bbox_to_anchor=(1.05, 1),
loc="upper left"
)

sns.boxplot(data=df, x='stroke', y='age', hue='Residence_type', ax=axes[1][1])
axes[1][1].legend(
title="Residence Type",
bbox_to_anchor=(1.05, 1),
loc="upper left"
    )

sns.boxplot(data=df, x='stroke', y='age', hue='heart_disease', ax=axes[2][0])
axes[2][0].legend(
title="Heart Disease",
bbox_to_anchor=(1.05, 1),
loc="upper left"
    )

sns.boxplot(data=df, x='stroke', y='age', hue='hypertension', ax=axes[2][1])
axes[2][1].legend(
title="Hypertension",
bbox_to_anchor=(1.05, 1),
loc="upper left"
)

plt.tight_layout()

# %%
# Fix: handle environments where sns.striplot is not available
fig,axes = plt.subplots(nrows=3, ncols=2, figsize=(15,10))

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='gender', jitter=0.25, alpha=0.6, ax=axes[0][0])
    axes[0][0].legend(
    title="Gender",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["gender"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='weight_category', jitter=0.25, alpha=0.6, ax=axes[0][1])
    axes[0][1].legend(
    title="Weight Category",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["weight_category"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='work_type', jitter=0.25, alpha=0.6, ax=axes[1][0])
    axes[1][0].legend(
    title="Work Type",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["work_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='Residence_type', jitter=0.25, alpha=0.6, ax=axes[1][1])
    axes[1][1].legend(
        title="Residence Type",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["Residence_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='heart_disease', jitter=0.25, alpha=0.6, ax=axes[2][0])
    axes[2][0].legend(
        title="Heart Disease",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["heart_disease"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='bmi', hue='hypertension', jitter=0.25, alpha=0.6, ax=axes[2][1])
    axes[2][1].legend(
    title="Hypertension",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
    plt.legend(
        title="Hypertension",
        bbox_to_anchor=(1.05, 1),
        loc="upper left",
        borderaxespad=0
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["bmi"],
        hue=df["hypertension"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])
plt.tight_layout()
plt.show()

# %%
# Fix: handle environments where sns.striplot is not available
fig,axes = plt.subplots(nrows=3, ncols=2, figsize=(15,10))

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='gender', jitter=0.25, alpha=0.6, ax=axes[0][0])
    axes[0][0].legend(
    title="Gender",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_glucose_level"],
        hue=df["gender"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='weight_category', jitter=0.25, alpha=0.6, ax=axes[0][1])
    axes[0][1].legend(
    title="Weight Category",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_glucose_level"],
        hue=df["weight_category"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])


if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='work_type', jitter=0.25, alpha=0.6, ax=axes[1][0])
    axes[1][0].legend(
    title="Work Type",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_glucose_level"],
        hue=df["work_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='Residence_type', jitter=0.25, alpha=0.6, ax=axes[1][1])
    axes[1][1].legend(
        title="Residence Type",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_gluose_level"],
        hue=df["Residence_type"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='heart_disease', jitter=0.25, alpha=0.6, ax=axes[2][0])
    axes[2][0].legend(
        title="Heart Disease",
        bbox_to_anchor=(1.05, 1),
        loc="upper left"
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_glucose_level"],
        hue=df["heart_disease"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])

if hasattr(sns, "stripplot"):
    sns.stripplot(data=df, x='stroke', y='avg_glucose_level', hue='hypertension', jitter=0.25, alpha=0.6, ax=axes[2][1])
    axes[2][1].legend(
    title="Hypertension",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)
    plt.legend(
        title="Hypertension",
        bbox_to_anchor=(1.05, 1),
        loc="upper left",
        borderaxespad=0
    )
else:
    jitter = np.random.uniform(-0.18, 0.18, size=len(df))
    sns.scatterplot(
        x=df["stroke"] + jitter,
        y=df["avg_glucose_level"],
        hue=df["hypertension"],
        alpha=0.6,
        s=18
    )
    plt.xticks([0, 1], ["0", "1"])
plt.tight_layout()
plt.show()

# %%
df_corr=df[['age','bmi','avg_glucose_level','heart_disease','hypertension','ever_married_Yes','gender_Male','stroke']].corr(method='pearson')
df_corr
# Out:
#                         age       bmi  avg_glucose_level  heart_disease  \
# age                1.000000  0.351097           0.199720       0.263796
# bmi                0.351097  1.000000           0.151529       0.044654
# avg_glucose_level  0.199720  0.151529           1.000000       0.139785
# heart_disease      0.263796  0.044654           0.139785       1.000000
# hypertension       0.276398  0.154520           0.156811       0.108306
# ever_married_Yes   0.679125  0.356780           0.133309       0.114644
# gender_Male       -0.027623 -0.024292           0.053852       0.085717
# stroke             0.245257  0.042700           0.115652       0.134914
#
#                    hypertension  ever_married_Yes  gender_Male    stroke
# age                    0.276398          0.679125    -0.027623  0.245257
# bmi                    0.154520          0.356780    -0.024292  0.042700
# avg_glucose_level      0.156811          0.133309     0.053852  0.115652
# ...

# %%
mask=np.zeros_like(df_corr,dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.set_theme(style="whitegrid")
sns.heatmap(df_corr, mask=mask, annot=True, cmap='plasma', linewidths=0.5, annot_kws={"size":8})
plt.show()

# %%
df.groupby(["hypertension", "stroke"]).size()
# Out:
# hypertension  stroke
# 0             0         4429
#               1          183
# 1             0          432
#               1           66
# dtype: int64

# %%
import pingouin as pg
import scipy
pg.normality(data=df, alpha=0.05)
# Out:
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 5110.
#   res = hypotest_fun_out(*samples, **kwds)
#                              W          pval  normal
# hypertension          0.337164  6.506703e-87   False
# heart_disease         0.235305  3.624412e-90   False
# bmi                   0.979031  8.008392e-27   False
# avg_glucose_level     0.875610  2.315612e-53   False
# stroke                0.220183  1.284463e-90   False
# gender_Male           0.625755  1.643667e-74   False
# gender_Other          0.002959  2.279647e-96   False
# age                   0.967243  1.378936e-32   False
# ever_married_Yes      0.600158  6.765160e-76   False
# Residence_type_Urban  0.636531  6.660335e-74   False
# work_type_encoded     0.818090  2.991361e-60   False

# %%
import scipy.stats as stats
import pandas as pd

expected, observed, stats = pg.chi2_independence(data=df, x='hypertension', y='stroke')
stats
# Out:
#                  test    lambda       chi2  dof          pval    cramer  \
# 0             pearson  1.000000  81.605368  1.0  1.661622e-19  0.126371
# 1        cressie-read  0.666667  72.922988  1.0  1.348088e-17  0.119460
# 2      log-likelihood  0.000000  59.769802  1.0  1.066269e-14  0.108151
# 3       freeman-tukey -0.500000  52.612863  1.0  4.062199e-13  0.101469
# 4  mod-log-likelihood -1.000000  47.113056  1.0  6.700785e-12  0.096020
# 5              neyman -2.000000  39.537634  1.0  3.217978e-10  0.087962
#
#       power
# 0  1.000000
# 1  1.000000
# 2  1.000000
# 3  1.000000
# 4  1.000000
# 5  0.999992

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    2.088785e-21
# Name: pval, dtype: float64

# %%
expected, observed, stats = pg.chi2_independence(data=df, x='gender', y='stroke')
stats
# Out:
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\pingouin\contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7994: RuntimeWarning: divide by zero encountered in power
#   terms = f_obs * ((f_obs / f_exp)**lambda_ - 1)
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7994: RuntimeWarning: invalid value encountered in multiply
#   terms = f_obs * ((f_obs / f_exp)**lambda_ - 1)
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7991: RuntimeWarning: divide by zero encountered in divide
# ...

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    0.789549
# Name: pval, dtype: float64

# %%
expected, observed, stats = pg.chi2_independence(data=df, x='weight_category', y='stroke')
stats
# Out:
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
#                  test    lambda        chi2  dof          pval    cramer  \
# 0             pearson  1.000000   45.197812  4.0  3.616694e-09  0.094048
# 1        cressie-read  0.666667   47.603631  4.0  1.141528e-09  0.096518
# 2      log-likelihood  0.000000   56.150733  4.0  1.864440e-11  0.104826
# 3       freeman-tukey -0.500000   69.021303  4.0  3.652357e-14  0.116220
# 4  mod-log-likelihood -1.000000   94.780099  4.0  1.269168e-19  0.136191
# 5              neyman -2.000000  288.292726  4.0  3.629411e-61  0.237523
#
#       power
# 0  0.999964
# 1  0.999983
# 2  0.999999
# 3  1.000000
# 4  1.000000
# 5  1.000000

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    3.616694e-09
# Name: pval, dtype: float64

# %%
expected, observed, stats = pg.chi2_independence(data=df, x='ever_married_Yes', y='stroke')
stats
# Out:
#                  test    lambda        chi2  dof          pval    cramer  \
# 0             pearson  1.000000   58.923890  1.0  1.638902e-14  0.107383
# 1        cressie-read  0.666667   61.812674  1.0  3.777352e-15  0.109984
# 2      log-likelihood  0.000000   69.605351  1.0  7.244010e-17  0.116711
# 3       freeman-tukey -0.500000   77.800567  1.0  1.139875e-18  0.123390
# 4  mod-log-likelihood -1.000000   88.805989  1.0  4.354954e-21  0.131829
# 5              neyman -2.000000  123.915917  1.0  8.789018e-29  0.155723
#
#    power
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    1.638902e-14
# Name: pval, dtype: float64

# %%
expected, observed, stats = pg.chi2_independence(data=df, x='work_type', y='stroke')
stats
# Out:
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\pingouin\contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\pingouin\contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7994: RuntimeWarning: divide by zero encountered in power
#   terms = f_obs * ((f_obs / f_exp)**lambda_ - 1)
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7994: RuntimeWarning: invalid value encountered in multiply
#   terms = f_obs * ((f_obs / f_exp)**lambda_ - 1)
# c:\Users\Lailah\vscode-project\DA2_Assessment\.venv\Lib\site-packages\scipy\stats\_stats_py.py:7991: RuntimeWarning: divide by zero encountered in divide
# ...

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    5.397708e-10
# Name: pval, dtype: float64

# %%
expected, observed, stats = pg.chi2_independence(data=df, x='heart_disease', y='stroke')
stats
# Out:
#                  test    lambda       chi2  dof          pval    cramer  \
# 0             pearson  1.000000  90.259561  1.0  2.088785e-21  0.132903
# 1        cressie-read  0.666667  77.193504  1.0  1.550025e-18  0.122908
# 2      log-likelihood  0.000000  58.724436  1.0  1.813748e-14  0.107201
# 3       freeman-tukey -0.500000  49.412060  1.0  2.074663e-12  0.098335
# 4  mod-log-likelihood -1.000000  42.639610  1.0  6.581308e-11  0.091347
# 5              neyman -2.000000  33.882000  1.0  5.855798e-09  0.081428
#
#       power
# 0  1.000000
# 1  1.000000
# 2  1.000000
# 3  1.000000
# 4  0.999998
# 5  0.999944

# %%
stats.query("test=='pearson'")['pval']
# Out:
# 0    2.088785e-21
# Name: pval, dtype: float64

# %%
# Convert 0/1 into readable labels BEFORE plotting
#df["Potability"] = df["Potability"].map({
#     0: "Not potable",
#     1: "Potable"
# })

# # Now calculate proportions
# Potability_count = df.value_counts('Potability', normalize=True)

# # Plot the pie chart
# plt.pie(
#     x=Potability_count,
#     labels=Potability_count.index,
#     autopct='%1.1f%%'
# )
# plt.show()

# %%
#fig=sns.pairplot(data=df[['RestingBP', 'Cholesterol', 'Age', 'MaxHR', 'HeartDisease']], hue='HeartDisease', plot_kws={'alpha': 0.5});
#for i, j in zip(*np.triu_indices_from(fig.axes, 1)):
    #fig.axes[i, j].set_visible(False)
#plt.show()

# %%
# sns.set_theme(style="white")
# mask = np.triu(np.ones_like(df_corr, dtype=bool))
# sns.heatmap(df_corr, mask=mask, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 8})
# plt.ylim(df_corr.shape[0], 0)
# plt.show()

# %% [markdown]
# Bivariate Analysis: Comparing the Impact of different features on water potability

# %%
# fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(15, 20))

# sns.boxplot(data=df, x='ph', y='Potability', ax=axes[0,0])
# #sns.swarmplot(data=df, x=x, y=y, ax=axes[1], dodge=True, size=3)
# sns.stripplot(data=df, x='ph', y='Potability', ax=axes[0,1])

# sns.boxplot(data=df, x='Hardness', y='Potability', ax=axes[1,0])
# sns.stripplot(data=df, x='Hardness', y='Potability', ax=axes[1,1])

# sns.boxplot(data=df, x='Solids', y='Potability', ax=axes[2,0])
# sns.stripplot(data=df, x='Solids', y='Potability', ax=axes[2,1])

# sns.boxplot(data=df, x='Chloramines', y='Potability', ax=axes[3,0])
# sns.stripplot(data=df, x='Chloramines', y='Potability', ax=axes[3,1])

# sns.boxplot(data=df, x='Sulfate', y='Potability', ax=axes[4,0])
# sns.stripplot(data=df, x='Sulfate', y='Potability', ax=axes[4,1])

# sns.boxplot(data=df, x='Conductivity', y='Potability', ax=axes[5,0])
# sns.stripplot(data=df, x='Conductivity', y='Potability', ax=axes[5,1])

# sns.boxplot(data=df, x='Organic_carbon', y='Potability', ax=axes[6,0])
# sns.stripplot(data=df, x='Organic_carbon', y='Potability', ax=axes[6,1])

# sns.boxplot(data=df, x='Trihalomethanes', y='Potability', ax=axes[7,0])
# sns.stripplot(data=df, x='Trihalomethanes', y='Potability', ax=axes[7,1])


# plt.tight_layout(pad=3.0)
# plt.show()

# %% [markdown]
# Python had issues running the swarmplot with my data; The issue: When there are too many data points or the markers are too large, seaborn cannot find non-overlapping positions for all points. The percentages indicate how many points couldn't be placed:
#
# 16.9% in the first plot
# 13.0% in the second plot
# 33.4% in the third plot (most severe)
# 21.0% in the fourth plot
#
# so coppilot suggested using a striplot which worked out much better

# %% [markdown]
# Most water‑quality features show substantial overlap between potable and non‑potable samples. No single variable provides clear separation, indicating that potability depends on a combination of factors rather than any one parameter. This supports the use of multivariate machine‑learning models to capture complex interactions.

# %%
# sns.lmplot(data=df, x='Hardness', y='ph', hue='Potability', height=5, aspect=1.5)

# plt.show()

# %%
# sns.lmplot(data=df, x='Hardness', y='Chloramines', hue ='Potability', height=5, aspect=1.5)

# plt.show()

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.
